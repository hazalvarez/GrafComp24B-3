# %% [markdown]
# <div style="text-align: center;">
#
# # **UNIVERSIDAD AUTÓNOMA DEL ESTADO DE MÉXICO**
# # **CU UAEM Zumpango**
#
# ### **Ingeniería en computación**
#
# ### **Graficación Computacional**
#
# ### **Presenta:**
# #### Citli López Campos
#
# ### **Fecha:**
# #### 07 de octubre de 2024
#
# ### **Docente:**
# #### Hazem Álvarez Rodriguez
#
# ---
#
# ### **ALGORITMO PARA CREAR UNA ENVOLVENTE CONVEXA**
#
# </div>

# %%
#SE IMPORTAN LAS LIBRERIAS A UTILIZAR
import random as rand
import numpy as np
import matplotlib.pyplot as plt

# %%
#FUNCIÓN PARA CALCULAR LA ENVOLVENTE CONVEXA EN SENTIDO HORARIO 
def turn_right():
    array = [coord_points[0], coord_points[1]]
    for i in range (2, len(coord_points)):
        array.append(coord_points[i])
        while len(array) > 2 and np.linalg.det([array[-3], array[-2], array[-1]]) > 0:
            array.pop(-2)
    return array
#FUNCIÓN PRINCIPAL PARA CALCULAR LA CENVOLVENTE CONVEXA 
def convex_hull():
    coord_points.sort() #ORDENA LOS PUNTOS POR COORDENADAS X 
    l_upper = turn_right() #CALCULA LA PARTE SUPERIOR DE LA ENVOLVENTE
    coord_points.reverse() #INVIERTE EL ORDEN DE LOS PUNTOS
    l_lower = turn_right() #CALCULA LA PARTE INFERIOR DE LA ENVOLVENTE 
    l = l_upper + l_lower #COMBINA AMBAS PARTES
    return l
#FUNCIÓN PARA GRAFICAR LOS PUNTOS Y LA ENVOLVENTE CONVEXA 
def graph(convex_pol, coord_points):
    #Acomodando listas adecuadas 
    x_points = [i[0] for i in coord_points]
    y_points = [i[1] for i in coord_points]

    x_polygon = [i[0] for i in convex_pol]
    y_polygon = [i[1] for i in convex_pol]

    #definiendo limites de la grafica
    x_lim_der = max(x_points)+1
    y_lim_sup = max(y_points)+1
    x_lim_izq = min(x_points)-1
    y_lim_inf = min(y_points)-1

    # Asignacion de los liites extremos
    plt.xlim(x_lim_izq,x_lim_der)
    plt.ylim(y_lim_inf, y_lim_sup)

    #Graficacion 
    plt.title('Problema: convex hull')
    plt.xlabel('Eje de las abscisas')
    plt.xlabel('Eje de las ordenadas')
    plt.plot(x_points, y_points, 'ko') #PUNTOS ORIGINALES
    plt.plot(x_polygon, y_polygon, 'g-', linewidth = 3.0) #ENVOLVENTE CONVEXA  
    
#Generacion de coordenadas de forma aleatorea
num_points = 100
coord_points = []
for i in range(num_points): coord_points.append([rand.uniform(0,50), rand.uniform(0,100), 1.0])

# creacion y graficacion
convex_pol = convex_hull()
graph(convex_pol,coord_points)

# %%
#FUNCIÓN PARA CALCULAR LA ENVOLVENTE CONVEXA EN SENTIDO HORARIO 
def turn_right():
    array = [coord_points[0], coord_points[1]]
    for i in range (9, len(coord_points)):
        array.append(coord_points[i])
        while len(array) > 2 and np.linalg.det([array[-3], array[-2], array[-1]]) > 0:
            array.pop(-2)
    return array
#FUNCIÓN PRINCIPAL PARA CALCULAR LA CENVOLVENTE CONVEXA 
def convex_hull():
    coord_points.sort() #ORDENA LOS PUNTOS POR COORDENADAS X 
    l_upper = turn_right() #CALCULA LA PARTE SUPERIOR DE LA ENVOLVENTE
    coord_points.reverse() #INVIERTE EL ORDEN DE LOS PUNTOS
    l_lower = turn_right() #CALCULA LA PARTE INFERIOR DE LA ENVOLVENTE 
    l = l_upper + l_lower #COMBINA AMBAS PARTES
    return l
#FUNCIÓN PARA GRAFICAR LOS PUNTOS Y LA ENVOLVENTE CONVEXA 
def graph(convex_pol, coord_points):
    #Acomodando listas adecuadas 
    x_points = [i[0] for i in coord_points]
    y_points = [i[1] for i in coord_points]

    x_polygon = [i[0] for i in convex_pol]
    y_polygon = [i[1] for i in convex_pol]

    #definiendo limites de la grafica
    x_lim_der = max(x_points)+8
    y_lim_sup = max(y_points)+8
    x_lim_izq = min(x_points)-8
    y_lim_inf = min(y_points)-8

    # Asignacion de los liites extremos
    plt.xlim(x_lim_izq,x_lim_der)
    plt.ylim(y_lim_inf, y_lim_sup)

    #Graficacion 
    plt.title('Problema: convex hull ejercicio')
    plt.xlabel('Eje de las abscisas')
    plt.xlabel('Eje de las ordenadas')
    plt.plot(x_points, y_points, 'ko') #PUNTOS ORIGINALES
    plt.plot(x_polygon, y_polygon, 'm-', linewidth = 3.0) #ENVOLVENTE CONVEXA  
    
#Generacion de coordenadas de forma aleatorea
num_points = 30
coord_points = []
for i in range(num_points): coord_points.append([rand.uniform(0,50), rand.uniform(0,100), 1.0])

# creacion y graficacion
convex_pol = convex_hull()
graph(convex_pol,coord_points)

# %%
#FUNCIÓN PARA CALCULAR LA ENVOLVENTE CONVEXA EN SENTIDO HORARIO 
def turn_right():
    array = [coord_points[0], coord_points[1]]
    for i in range (1, len(coord_points)):
        array.append(coord_points[i])
        while len(array) > 4 and np.linalg.det([array[-3], array[-2], array[-1]]) > 0:
            array.pop(-2)
    return array
#FUNCIÓN PRINCIPAL PARA CALCULAR LA CENVOLVENTE CONVEXA 
def convex_hull():
    coord_points.sort() #ORDENA LOS PUNTOS POR COORDENADAS X 
    l_upper = turn_right() #CALCULA LA PARTE SUPERIOR DE LA ENVOLVENTE
    coord_points.reverse() #INVIERTE EL ORDEN DE LOS PUNTOS
    l_lower = turn_right() #CALCULA LA PARTE INFERIOR DE LA ENVOLVENTE 
    l = l_upper + l_lower #COMBINA AMBAS PARTES
    return l
#FUNCIÓN PARA GRAFICAR LOS PUNTOS Y LA ENVOLVENTE CONVEXA 
def graph(convex_pol, coord_points):
    #Acomodando listas adecuadas 
    x_points = [i[0] for i in coord_points]
    y_points = [i[1] for i in coord_points]

    x_polygon = [i[0] for i in convex_pol]
    y_polygon = [i[1] for i in convex_pol]

    #definiendo limites de la grafica
    x_lim_der = max(x_points)+6
    y_lim_sup = max(y_points)+6
    x_lim_izq = min(x_points)-6
    y_lim_inf = min(y_points)-6

    # Asignacion de los liites extremos
    plt.xlim(x_lim_izq,x_lim_der)
    plt.ylim(y_lim_inf, y_lim_sup)

    #Graficacion 
    plt.title('Problema: convex hull ejercicio 2')
    plt.xlabel('Eje de las abscisas')
    plt.xlabel('Eje de las ordenadas')
    plt.plot(x_points, y_points, 'ko') #PUNTOS ORIGINALES
    plt.plot(x_polygon, y_polygon, 'p-', linewidth = 5.0) #ENVOLVENTE CONVEXA  a color azul y el grosor 
    
#Generacion de coordenadas de forma aleatorea
#EL NUMERO DE PUNTOS CAMBIO A 70, UN PUNTO MEDIO ENTRE EL EJERCICIO ORIGINAL Y EL SEGUNDO 
num_points = 70
coord_points = []
for i in range(num_points): coord_points.append([rand.uniform(0,50), rand.uniform(0,100), 10.0])

# creacion y graficacion
convex_pol = convex_hull()
graph(convex_pol,coord_points)
